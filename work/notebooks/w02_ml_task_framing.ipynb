# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/si-ux/FlyrankAI-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Ranking/Scoring since it will provide real insights.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The prediction would help the SEO/content team make data‑driven decisions about keyword and content strategy, errors in those decisions translate into measurable traffic, revenue, and resource losses.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# R^2, MSE.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# Portable setup — works in Colab and locally, no hardcoded paths.
import os, sys, subprocess
from pathlib import Path
import pandas as pd

REPO_URL = "https://github.com/si-ux/FlyrankAI-Internship"
REPO_DIR = "FlyrankAI-Internship"
MARKER = "data/raw/content_refresh_anonymized.csv"

if "google.colab" in sys.modules and not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

ROOT = Path(REPO_DIR).resolve() if os.path.isdir(REPO_DIR) else Path.cwd()
while not (ROOT / MARKER).exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
assert (ROOT / MARKER).exists(), "starter CSV not found — run this from inside the repo"

df = pd.read_csv(ROOT / MARKER)

# One row = one pseudonymized content item, observed over a trailing 90-day window.
df["is_declining_label"] = (df["trend_direction"] == "down").astype(int)

print(f"Unit of analysis: {len(df):,} content items across {df['client_id'].nunique()} clients")
print(f"Label base rate: {df['is_declining_label'].mean():.1%} declining")
print(df["is_declining_label"].value_counts())
# Out:
# Unit of analysis: 30,000 content items across 32 clients
# Label base rate: 54.2% declining
# is_declining_label
# 1    16262
# 0    13738
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# It would have to be multiple such statements which makes the code redundunt and not useful.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
